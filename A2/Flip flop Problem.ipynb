# %% [markdown]
# # **Flip Flop**

# %%
# !pip install mlrose-hiive
# Out:
# Requirement already satisfied: mlrose-hiive in /usr/local/lib/python3.7/dist-packages (2.2.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from mlrose-hiive) (1.4.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from mlrose-hiive) (1.1.5)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from mlrose-hiive) (2.5)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from mlrose-hiive) (1.0.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from mlrose-hiive) (0.22.2.post1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from mlrose-hiive) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->mlrose-hiive) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->mlrose-hiive) (2018.9)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.7/dist-packages (from networkx->mlrose-hiive) (4.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->mlrose-hiive) (1.15.0)

# %%
import mlrose_hiive
import matplotlib.pyplot as plt
import time

# %% [markdown]
# # **Create Problem**

# %%
len = 100
problem = mlrose_hiive.FlipFlopOpt(len)
attempts = 100
iters = 100
restarts = 10
schedule = mlrose_hiive.GeomDecay(init_temp=1, decay=0.095, min_temp=0.1)

# %% [markdown]
# # **Random Hill Climb**

# %%
start_time = time.time()  
rhc_best_state, rhc_best_fitness, rhc_best_curve = mlrose_hiive.random_hill_climb(problem, max_attempts=attempts, max_iters=iters, init_state=None, curve=True, random_state=None, restarts=0)
print("--- %s RHC seconds ---" % (time.time() - start_time))
# Out:
# --- 0.03685426712036133 RHC seconds ---

# %% [markdown]
# # **Simulated Annealing**

# %%
start_time = time.time()
sa_best_state, sa_best_fitness, sa_best_curve = mlrose_hiive.simulated_annealing(problem, schedule=schedule, max_attempts=attempts, max_iters=iters, init_state=None, curve=True, random_state=None)
print("--- %s SA seconds ---" % (time.time() - start_time))
# Out:
# --- 0.04557466506958008 SA seconds ---

# %% [markdown]
# # **Genetic Alg**

# %%
start_time = time.time()
ga_best_state, ga_best_fitness, ga_best_curve = mlrose_hiive.genetic_alg(problem, pop_size=200, mutation_prob=0.1, max_attempts=attempts, max_iters=iters, curve=True, random_state=None)
print("--- %s GA seconds ---" % (time.time() - start_time))
# Out:
# --- 0.590721607208252 GA seconds ---

# %% [markdown]
# # **MIMIC**

# %%
start_time = time.time()
mimic_best_state, mimic_best_fitness, mimic_best_curve = mlrose_hiive.mimic(problem, pop_size=500, keep_pct=0.2, max_attempts=attempts, max_iters=iters, curve=True, random_state=None)
print("--- %s MIMIC seconds ---" % (time.time() - start_time))
# Out:
# --- 114.26909828186035 MIMIC seconds ---

# %% [markdown]
# # **Curves**

# %%
plt.grid()
rhc_x = [x[0] for x in rhc_best_curve]
rhc_y = [x[1] for x in rhc_best_curve]
sa_x = [x[0] for x in sa_best_curve]
sa_y = [x[1] for x in sa_best_curve]
ga_x = [x[0] for x in ga_best_curve]
ga_y = [x[1] for x in ga_best_curve]
mimic_x = [x[0] for x in mimic_best_curve]
mimic_y = [x[1] for x in mimic_best_curve]
plt.plot(rhc_x, rhc_y,color='green', label="RHC")
plt.plot(sa_x, sa_y, color='red', label="SA")
plt.plot(ga_x, ga_y, color='orange', label="GA")
plt.plot(mimic_x, mimic_y, color='blue', label="MIMIC")
plt.xlabel("Iters"), plt.ylabel("Value"), plt.legend(loc="best"),plt.title("Flip Flop Problem")
plt.tight_layout()
plt.show()
